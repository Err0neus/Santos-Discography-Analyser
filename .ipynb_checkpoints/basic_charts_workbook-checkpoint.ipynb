# %% [markdown]
# # Visualisations

# %%
from UI.plots import plots as plots
plots()
# Out:
# Accordion(children=(VBox(children=(IntSlider(value=6, description='Period Size (# of years)', max=10, min=1, s…
