# %% [markdown]
# # Santos lyrics analyzer

# %%
from project_santos.UI import UI
UI()
# Out:
# Accordion(children=(VBox(children=(Text(value='Nic Cav & The Bad seeds'), Button(description='Get discography'…
