# %% [markdown]
# # Santos lyrics analyzer

# %%
from functions.UI import UI
UI()
# Out:
# Accordion(children=(Tab(children=(VBox(children=(Text(value='Bruno mars'), Button(description='Get discography…
