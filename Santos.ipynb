# %% [markdown]
# # Santos lyrics analyzer

# %%
from functions.UI import UI
UI()
# Out:
# Accordion(children=(VBox(children=(Text(value='Nick Cave And The Bad Seeds'), Button(description='Get discogra…
